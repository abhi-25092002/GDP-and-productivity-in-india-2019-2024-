# %% [markdown]
# # GDP and productivity of indian cities(2019-2024) analysis

# %% [markdown]
# 1. Which Year highest and lowest analysis of GDP and productivity :-

# %% [markdown]
# 2. Comparison Between both Unemploment Ratio :-

# %% [markdown]
# 3. City regarding R&D Expenditure (% of GDP) in india (2019-2024) :-

# %% [markdown]
# 4. Analysis about density of Patents per 100,000 Inhabitants :-

# %% [markdown]
# 5. Comparison between Unemployment Rate (%) and ICT Sector Employment (%) :-

# %% [markdown]
# 6. Which number of R&D Expenditure (% of GDP) highest and lowest :-

# %% [markdown]
# 7. Analysis of SME employment(%) according to Cities :-

# %% [markdown]
# 8. Analysis of City regarding ICT Sector Employment (%) :-

# %% [markdown]
# 9. All Employment ratio comparison with year :-

# %% [markdown]
# 10. Both Unemployment ratio analysis regarding Cities :-

# %% [markdown]
# 11. Year according Unemployment rate in india cities :-

# %% [markdown]
# 12. EDA :-

# %% [markdown]
# 13. BIVARIANT ANALYSIS :-

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\abhip\Documents\Downloads\gdp and productivity of indian cities(2019-2024)\Economy_Productivity_SD_India.csv")
df
# Out:
#           City  Year  R&D Expenditure (% of GDP)  \
# 0    Ahmedabad  2019                        1.06
# 1    Ahmedabad  2020                        1.93
# 2    Ahmedabad  2021                        1.60
# 3    Ahmedabad  2022                        1.40
# 4    Ahmedabad  2023                        0.73
# ..         ...   ...                         ...
# 175     Ranchi  2020                        0.76
# 176     Ranchi  2021                        1.54
# 177     Ranchi  2022                        1.08
# 178     Ranchi  2023                        1.91
# 179     Ranchi  2024                        0.71
#
#      Patents per 100,000 Inhabitants  Unemployment Rate (%)  \
# 0                                3.4                    5.6
# 1                                2.1                    6.6
# 2                                6.6                    5.8
# 3                                6.3                    6.2
# 4                                2.9                    7.8
# ...

# %%
df.columns
# Out:
# Index(['City', 'Year', 'R&D Expenditure (% of GDP)',
#        'Patents per 100,000 Inhabitants', 'Unemployment Rate (%)',
#        'Youth Unemployment Rate (%)', 'SME Employment (%)',
#        'Tourism Sector Employment (%)', 'ICT Sector Employment (%)'],
#       dtype='object')

# %%
df.describe(include='all')
# Out:
#              City         Year  R&D Expenditure (% of GDP)  \
# count         180   180.000000                  180.000000
# unique         30          NaN                         NaN
# top     Ahmedabad          NaN                         NaN
# freq            6          NaN                         NaN
# mean          NaN  2021.500000                    1.208167
# std           NaN     1.712589                    0.440471
# min           NaN  2019.000000                    0.510000
# 25%           NaN  2020.000000                    0.827500
# 50%           NaN  2021.500000                    1.195000
# 75%           NaN  2023.000000                    1.590000
# max           NaN  2024.000000                    1.980000
#
#         Patents per 100,000 Inhabitants  Unemployment Rate (%)  \
# count                        180.000000             180.000000
# unique                              NaN                    NaN
# top                                 NaN                    NaN
# ...

# %%
df.dropna(how='any',inplace=True)

# %%
df.head(10)
# Out:
#         City  Year  R&D Expenditure (% of GDP)  \
# 0  Ahmedabad  2019                        1.06
# 1  Ahmedabad  2020                        1.93
# 2  Ahmedabad  2021                        1.60
# 3  Ahmedabad  2022                        1.40
# 4  Ahmedabad  2023                        0.73
# 5  Ahmedabad  2024                        0.73
# 6  Bengaluru  2019                        0.59
# 7  Bengaluru  2020                        1.80
# 8  Bengaluru  2021                        1.40
# 9  Bengaluru  2022                        1.56
#
#    Patents per 100,000 Inhabitants  Unemployment Rate (%)  \
# 0                              3.4                    5.6
# 1                              2.1                    6.6
# 2                              6.6                    5.8
# 3                              6.3                    6.2
# 4                              2.9                    7.8
# 5                              5.1                    5.5
# ...

# %%
df.tail()
# Out:
#        City  Year  R&D Expenditure (% of GDP)  \
# 175  Ranchi  2020                        0.76
# 176  Ranchi  2021                        1.54
# 177  Ranchi  2022                        1.08
# 178  Ranchi  2023                        1.91
# 179  Ranchi  2024                        0.71
#
#      Patents per 100,000 Inhabitants  Unemployment Rate (%)  \
# 175                              5.0                    7.8
# 176                              1.6                    7.4
# 177                              4.7                    5.0
# 178                              6.7                    5.8
# 179                              4.7                    4.5
#
#      Youth Unemployment Rate (%)  SME Employment (%)  \
# 175                         11.7                20.1
# 176                         11.3                22.3
# 177                         11.9                37.4
# 178                          8.5                15.3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   City                             180 non-null    object
#  1   Year                             180 non-null    int64
#  2   R&D Expenditure (% of GDP)       180 non-null    float64
#  3   Patents per 100,000 Inhabitants  180 non-null    float64
#  4   Unemployment Rate (%)            180 non-null    float64
#  5   Youth Unemployment Rate (%)      180 non-null    float64
#  6   SME Employment (%)               180 non-null    float64
#  7   Tourism Sector Employment (%)    180 non-null    float64
#  8   ICT Sector Employment (%)        180 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 12.8+ KB

# %%
df.isnull().sum()
# Out:
# City                               0
# Year                               0
# R&D Expenditure (% of GDP)         0
# Patents per 100,000 Inhabitants    0
# Unemployment Rate (%)              0
# Youth Unemployment Rate (%)        0
# SME Employment (%)                 0
# Tourism Sector Employment (%)      0
# ICT Sector Employment (%)          0
# dtype: int64

# %% [markdown]
# # DATA CLEANING

# %%
df.dtypes
# Out:
# City                                object
# Year                                 int64
# R&D Expenditure (% of GDP)         float64
# Patents per 100,000 Inhabitants    float64
# Unemployment Rate (%)              float64
# Youth Unemployment Rate (%)        float64
# SME Employment (%)                 float64
# Tourism Sector Employment (%)      float64
# ICT Sector Employment (%)          float64
# dtype: object

# %%
df.head()
# Out:
#         City  Year  R&D Expenditure (% of GDP)  \
# 0  Ahmedabad  2019                        1.06
# 1  Ahmedabad  2020                        1.93
# 2  Ahmedabad  2021                        1.60
# 3  Ahmedabad  2022                        1.40
# 4  Ahmedabad  2023                        0.73
#
#    Patents per 100,000 Inhabitants  Unemployment Rate (%)  \
# 0                              3.4                    5.6
# 1                              2.1                    6.6
# 2                              6.6                    5.8
# 3                              6.3                    6.2
# 4                              2.9                    7.8
#
#    Youth Unemployment Rate (%)  SME Employment (%)  \
# 0                         11.8                38.5
# 1                         10.4                19.5
# 2                          8.9                16.7
# 3                         10.7                33.5
# 4                         10.5                29.4
#
# ...

# %%
a=df['City'].unique()
print(a)
print('--------------------------------------------------------------------------')
b=df['Year'].unique()
print(b)
print('--------------------------------------------------------------------------')
c=df['R&D Expenditure (% of GDP)'].unique()
print(c)
# Out:
# ['Ahmedabad' 'Bengaluru' 'Mumbai' 'Hyderabad' 'Chennai' 'Kolkata' 'Delhi'
#  'Pune' 'Surat' 'Jaipur' 'Lucknow' 'Kanpur' 'Nagpur' 'Indore' 'Bhopal'
#  'Patna' 'Vadodara' 'Ludhiana' 'Agra' 'Nashik' 'Faridabad' 'Meerut'
#  'Rajkot' 'Varanasi' 'Srinagar' 'Aurangabad' 'Dhanbad' 'Amritsar'
#  'Allahabad' 'Ranchi']
# --------------------------------------------------------------------------
# [2019 2020 2021 2022 2023 2024]
# --------------------------------------------------------------------------
# [1.06 1.93 1.6  1.4  0.73 0.59 1.8  1.56 0.53 1.95 1.75 0.82 0.77 0.78
#  0.96 1.29 1.15 0.94 1.42 0.71 1.05 1.18 1.68 0.8  1.27 1.39 0.57 1.41
#  0.76 0.6  1.92 1.71 0.65 1.53 1.16 0.68 1.24 0.55 1.86 0.89 1.49 0.97
#  1.28 1.32 1.66 1.91 1.84 1.88 0.63 0.79 0.99 1.08 0.91 1.74 1.04 0.92
#  1.31 1.7  0.61 1.98 0.51 1.72 1.59 0.67 1.79 1.43 1.   1.46 1.83 1.21
#  1.57 1.64 1.34 1.14 0.54 0.66 1.45 1.26 0.87 1.12 1.63 0.84 0.62 0.93
# ...

# %%
df.size
# Out:
# 1620

# %%
df.describe()
# Out:
#               Year  R&D Expenditure (% of GDP)  \
# count   180.000000                  180.000000
# mean   2021.500000                    1.208167
# std       1.712589                    0.440471
# min    2019.000000                    0.510000
# 25%    2020.000000                    0.827500
# 50%    2021.500000                    1.195000
# 75%    2023.000000                    1.590000
# max    2024.000000                    1.980000
#
#        Patents per 100,000 Inhabitants  Unemployment Rate (%)  \
# count                       180.000000             180.000000
# mean                          4.296667               6.160000
# std                           1.592893               1.260602
# min                           1.500000               4.000000
# 25%                           2.975000               5.100000
# 50%                           4.500000               6.200000
# 75%                           5.525000               7.300000
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 175    False
# 176    False
# 177    False
# 178    False
# 179    False
# Length: 180, dtype: bool

# %%
df.shape
# Out:
# (180, 9)

# %%
df.head()
# Out:
#         City  Year  R&D Expenditure (% of GDP)  \
# 0  Ahmedabad  2019                        1.06
# 1  Ahmedabad  2020                        1.93
# 2  Ahmedabad  2021                        1.60
# 3  Ahmedabad  2022                        1.40
# 4  Ahmedabad  2023                        0.73
#
#    Patents per 100,000 Inhabitants  Unemployment Rate (%)  \
# 0                              3.4                    5.6
# 1                              2.1                    6.6
# 2                              6.6                    5.8
# 3                              6.3                    6.2
# 4                              2.9                    7.8
#
#    Youth Unemployment Rate (%)  SME Employment (%)  \
# 0                         11.8                38.5
# 1                         10.4                19.5
# 2                          8.9                16.7
# 3                         10.7                33.5
# 4                         10.5                29.4
#
# ...

# %% [markdown]
# # DATA VISULIZATION :-

# %% [markdown]
# # 1.Which Year highest and lowest analysis of GDP and productivity :-

# %%
sns.scatterplot(df['Year'],color='darkgreen')
# Out:
# <Axes: ylabel='Year'>

# %% [markdown]
# # 2.Comparison Between both Unemploment Ratio :-

# %%
plt.subplots(figsize=(15,9))
sns.swarmplot(x='Unemployment Rate (%)',y='Youth Unemployment Rate (%)',data=df,color='r')
plt.grid()
plt.title('COMPARISON BETWEEN Unemployment Rate (%) AND Youth Unemployment Rate (%)',color='g')
# Out:
# C:\Users\abhip\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\abhip\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'COMPARISON BETWEEN Unemployment Rate (%) AND Youth Unemployment Rate (%)')

# %% [markdown]
# # 3.City regarding R&D Expenditure (% of GDP) in india (2019-2024) :-

# %%
plt.subplots(figsize=(15,8))
ax=sns.barplot(y=df['R&D Expenditure (% of GDP)'],x=df['City'])
ax.set_xticklabels(ax.get_xticklabels(),rotation=35)
plt.xlabel('R&D Expenditure (% of GDP)')
plt.ylabel('City')
plt.title('City regarding R&D Expenditure (% of GDP) in india (2019-2024)',color='r')
# Out:
# Text(0.5, 1.0, 'City regarding R&D Expenditure (% of GDP) in india (2019-2024)')

# %% [markdown]
# # 4.Analysis about density of Patents per 100,000 Inhabitants :-

# %%
sns.distplot(df['Patents per 100,000 Inhabitants'],color='brown')
# Out:
# C:\Users\abhip\AppData\Local\Temp\ipykernel_6784\188219606.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Patents per 100,000 Inhabitants'],color='brown')
# C:\Users\abhip\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Patents per 100,000 Inhabitants', ylabel='Density'>

# %%
df.head()
# Out:
#         City  Year  R&D Expenditure (% of GDP)  \
# 0  Ahmedabad  2019                        1.06
# 1  Ahmedabad  2020                        1.93
# 2  Ahmedabad  2021                        1.60
# 3  Ahmedabad  2022                        1.40
# 4  Ahmedabad  2023                        0.73
#
#    Patents per 100,000 Inhabitants  Unemployment Rate (%)  \
# 0                              3.4                    5.6
# 1                              2.1                    6.6
# 2                              6.6                    5.8
# 3                              6.3                    6.2
# 4                              2.9                    7.8
#
#    Youth Unemployment Rate (%)  SME Employment (%)  \
# 0                         11.8                38.5
# 1                         10.4                19.5
# 2                          8.9                16.7
# 3                         10.7                33.5
# 4                         10.5                29.4
#
# ...

# %% [markdown]
# # 5.Comparison between Unemployment Rate (%) and ICT Sector Employment (%) :-

# %%
sns.jointplot(x='Unemployment Rate (%)',y='SME Employment (%)',data=df,color='darkred')
plt.grid(color='black')
# Out:
# C:\Users\abhip\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\abhip\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # 6.Which number of R&D Expenditure (% of GDP) highest and lowest :-

# %%
df.groupby('R&D Expenditure (% of GDP)')['City'].count().nlargest(16).plot(kind = 'pie', autopct = '%1.1f%%')
# Out:
# <Axes: ylabel='City'>

# %% [markdown]
# # 7.Analysis of SME employment(%) according to Cities :-

# %%
plt.subplots(figsize=(30,15))
sns.violinplot(x=df['City'],y=df['SME Employment (%)'])
plt.xlabel('City',size=20,color='darkgreen')
plt.ylabel('SME Employment (%)',size=20,color='darkgreen')
# Out:
# Text(0, 0.5, 'SME Employment (%)')

# %% [markdown]
# # 8.Analysis of City regarding ICT Sector Employment (%) :-

# %%
plt.subplots(figsize=(18,10))
ax=sns.boxplot(x='City', y='ICT Sector Employment (%)', data=df,palette='rainbow')
ax.set_xticklabels(ax.get_xticklabels(),rotation=55)
# Out:
# [Text(0, 0, 'Ahmedabad'),
#  Text(1, 0, 'Bengaluru'),
#  Text(2, 0, 'Mumbai'),
#  Text(3, 0, 'Hyderabad'),
#  Text(4, 0, 'Chennai'),
#  Text(5, 0, 'Kolkata'),
#  Text(6, 0, 'Delhi'),
#  Text(7, 0, 'Pune'),
#  Text(8, 0, 'Surat'),
#  Text(9, 0, 'Jaipur'),
#  Text(10, 0, 'Lucknow'),
#  Text(11, 0, 'Kanpur'),
#  Text(12, 0, 'Nagpur'),
#  Text(13, 0, 'Indore'),
#  Text(14, 0, 'Bhopal'),
#  Text(15, 0, 'Patna'),
#  Text(16, 0, 'Vadodara'),
#  Text(17, 0, 'Ludhiana'),
#  Text(18, 0, 'Agra'),
#  Text(19, 0, 'Nashik'),
#  Text(20, 0, 'Faridabad'),
#  Text(21, 0, 'Meerut'),
#  Text(22, 0, 'Rajkot'),
#  Text(23, 0, 'Varanasi'),
#  Text(24, 0, 'Srinagar'),
#  Text(25, 0, 'Aurangabad'),
#  Text(26, 0, 'Dhanbad'),
#  Text(27, 0, 'Amritsar'),
#  Text(28, 0, 'Allahabad'),
#  Text(29, 0, 'Ranchi')]

# %% [markdown]
# # 9.All Employment ratio comparison with year :-

# %%
df2=df[['SME Employment (%)','Tourism Sector Employment (%)','ICT Sector Employment (%)','Year']]
df2.head(2)
# Out:
#    SME Employment (%)  Tourism Sector Employment (%)  \
# 0                38.5                            5.2
# 1                19.5                            4.2
#
#    ICT Sector Employment (%)  Year
# 0                       20.7  2019
# 1                        6.8  2020

# %%
sns.pairplot(df2,hue='Year',height=4)
# Out:
# C:\Users\abhip\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\abhip\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\abhip\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # 10.Both Unemployment ratio analysis regarding Cities :-

# %%
df3=df[['Unemployment Rate (%)','Youth Unemployment Rate (%)','City']]
df3.head()
# Out:
#    Unemployment Rate (%)  Youth Unemployment Rate (%)       City
# 0                    5.6                         11.8  Ahmedabad
# 1                    6.6                         10.4  Ahmedabad
# 2                    5.8                          8.9  Ahmedabad
# 3                    6.2                         10.7  Ahmedabad
# 4                    7.8                         10.5  Ahmedabad

# %%
sns.pairplot(df3,hue='City',height=2.5)
# Out:
# C:\Users\abhip\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\abhip\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # 11.Year according Unemployment rate in india cities :-

# %%
# Mapping in Year and then making graph about Year according Unemployment Rate

df['Year']=df['Year'].map({2019:'A',2020:'B',2021:'C',2022:'D',2023:'E',2024:'F'})

# %%
df.head(6)
# Out:
#         City Year  R&D Expenditure (% of GDP)  \
# 0  Ahmedabad    A                        1.06
# 1  Ahmedabad    B                        1.93
# 2  Ahmedabad    C                        1.60
# 3  Ahmedabad    D                        1.40
# 4  Ahmedabad    E                        0.73
# 5  Ahmedabad    F                        0.73
#
#    Patents per 100,000 Inhabitants  Unemployment Rate (%)  \
# 0                              3.4                    5.6
# 1                              2.1                    6.6
# 2                              6.6                    5.8
# 3                              6.3                    6.2
# 4                              2.9                    7.8
# 5                              5.1                    5.5
#
#    Youth Unemployment Rate (%)  SME Employment (%)  \
# 0                         11.8                38.5
# 1                         10.4                19.5
# 2                          8.9                16.7
# ...

# %%
sns.boxplot(x=df['Year'],y=df['Unemployment Rate (%)'],palette='rainbow')
# Out:
# <Axes: xlabel='Year', ylabel='Unemployment Rate (%)'>

# %% [markdown]
# # 12.EDA :-

# %%
df.hist(figsize=(25,20),color="olive")
# Out:
# array([[<Axes: title={'center': 'R&D Expenditure (% of GDP)'}>,
#         <Axes: title={'center': 'Patents per 100,000 Inhabitants'}>,
#         <Axes: title={'center': 'Unemployment Rate (%)'}>],
#        [<Axes: title={'center': 'Youth Unemployment Rate (%)'}>,
#         <Axes: title={'center': 'SME Employment (%)'}>,
#         <Axes: title={'center': 'Tourism Sector Employment (%)'}>],
#        [<Axes: title={'center': 'ICT Sector Employment (%)'}>, <Axes: >,
#         <Axes: >]], dtype=object)

# %% [markdown]
# # 13.BIVARIANT ANALYSIS :-

# %%
sns.pairplot(df)
# Out:
# C:\Users\abhip\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\abhip\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\abhip\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
